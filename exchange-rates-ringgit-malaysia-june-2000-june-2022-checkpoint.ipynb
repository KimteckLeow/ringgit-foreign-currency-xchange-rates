# %%
# Import necessary packages
from matplotlib.axes._axes import _log as matplotlib_axes_logger
import os
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import earthpy as et
import numpy as np

# Handle date time conversions between pandas and matplotlib
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# Dealing with error thrown by one of the plots
matplotlib_axes_logger.setLevel('ERROR')
import warnings
warnings.filterwarnings('ignore')

# Adjust font size and style of all plots in notebook with seaborn
sns.set(font_scale=1.5, style="whitegrid")

# Set working directory to earth-analytics
os.chdir(os.path.join(et.io.HOME, 
                      "earth-analytics", 
                      "data"))

# Import data from .csv file 
fname = os.path.join("forex",
                     "exchange-rates-rm-top10-june-2000-june-2022.csv")

# Import data using datetime and set index to datetime
xchange_rm_june_2000_june_2022 = pd.read_csv(fname,
                                parse_dates=['date'],
                                index_col=['date'])
xchange_rm_june_2000_june_2022
# Out:
#                USD     GBP     EUR  JPY100     CHF     AUD     CAD     SGD  \
# date
# 2010-06-01  3.2810  4.7496  4.0210  3.6051  2.8384  2.7432  3.1349  2.3388
# 2010-06-02  3.3100  4.8614  4.0423  3.6197  2.8607  2.7538  3.1382  2.3425
# 2010-06-03  3.2695  4.8019  4.0185  3.5471  2.8364  2.7693  3.1541  2.3319
# 2010-06-04  3.2700  4.7860  3.9825  3.5279  2.8336  2.7592  3.1424  2.3306
# 2010-06-07  3.3355  4.8130  3.9681  3.6584  2.8608  2.7118  3.1327  2.3501
# ...            ...     ...     ...     ...     ...     ...     ...     ...
# 2022-06-07  4.3970  5.5000  4.6969  3.3159  4.5265  3.1551  3.4912  3.1889
# 2022-06-08  4.3925  5.5205  4.6929  3.3013  4.5065  3.1630  3.5001  3.1945
# 2022-06-09  4.3920  5.5082  4.7126  3.2790  4.4945  3.1537  3.4970  3.1923
# 2022-06-10  4.3990  5.4970  4.6779  3.2805  4.4927  3.1240  3.4642  3.1855
# 2022-06-13  4.4150  5.4260  4.6322  3.2724  4.4632  3.1020  3.4460  3.1750
#
#              HKD100
# date
# 2010-06-01  42.1146
# ...

# %%
xchange_rm_june_2000_june_2022.describe()
# Out:
#                USD          GBP          EUR       JPY100          CHF  \
# count  2953.000000  2953.000000  2953.000000  2953.000000  2953.000000
# mean      3.755005     5.348644     4.498481     3.641806     3.946513
# std       0.506687     0.387001     0.327639     0.310058     0.486314
# min       2.938500     4.563300     3.815800     2.837000     2.833600
# 25%       3.184800     4.977000     4.209900     3.514000     3.474400
# 50%       4.036000     5.384400     4.583900     3.711700     4.104000
# 75%       4.182500     5.532400     4.763000     3.864000     4.392900
# max       4.499500     6.782500     5.115700     4.189000     4.678500
#
#               AUD          CAD          SGD       HKD100
# count  2953.00000  2953.000000  2953.000000  2953.000000
# mean      3.04635     3.130912     2.815839    48.259773
# std       0.15212     0.125096     0.280338     6.450577
# min       2.44870     2.846200     2.304700    37.721000
# ...

# %%
# Where is the date column
xchange_rm_june_2000_june_2022.dtypes
# Out:
# USD       float64
# GBP       float64
# EUR       float64
# JPY100    float64
# CHF       float64
# AUD       float64
# CAD       float64
# SGD       float64
# HKD100    float64
# dtype: object

# %%
xchange_rm_june_2000_june_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2953 entries, 2010-06-01 to 2022-06-13
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   USD     2953 non-null   float64
#  1   GBP     2953 non-null   float64
#  2   EUR     2953 non-null   float64
#  3   JPY100  2953 non-null   float64
#  4   CHF     2953 non-null   float64
#  5   AUD     2953 non-null   float64
#  6   CAD     2953 non-null   float64
#  7   SGD     2953 non-null   float64
#  8   HKD100  2953 non-null   float64
# dtypes: float64(9)
# memory usage: 230.7 KB

# %%
xchange_rm_june_2000_june_2022.columns
# Out:
# Index(['USD', 'GBP', 'EUR', 'JPY100', 'CHF', 'AUD', 'CAD', 'SGD', 'HKD100'], dtype='object')

# %%
xchange_rm_sgd_june_2000_june_2022 = xchange_rm_june_2000_june_2022[['SGD']]
xchange_rm_sgd_june_2000_june_2022
# Out:
#                SGD
# date
# 2010-06-01  2.3388
# 2010-06-02  2.3425
# 2010-06-03  2.3319
# 2010-06-04  2.3306
# 2010-06-07  2.3501
# ...            ...
# 2022-06-07  3.1889
# 2022-06-08  3.1945
# 2022-06-09  3.1923
# 2022-06-10  3.1855
# 2022-06-13  3.1750
#
# [2953 rows x 1 columns]

# %%
xchange_rm_sgd_june_2000_june_2022.columns
# Out:
# Index(['SGD'], dtype='object')

# %%
xchange_rm_sgd_june_2000_june_2022.describe()
# Out:
#                SGD
# count  2953.000000
# mean      2.815839
# std       0.280338
# min       2.304700
# 25%       2.508100
# 50%       2.977100
# 75%       3.056600
# max       3.200400

# %%
# Challenge 1(a): Open and Plot a CSV File with Time Series Data

# Create figure and plot space
fig, ax = plt.subplots(figsize=(20, 15))
 
# Add x-axis and y-axis
ax.scatter(xchange_rm_sgd_june_2000_june_2022.index.values,
        xchange_rm_sgd_june_2000_june_2022['SGD'],
        color='blue')
 
# Set title and labels for axes
ax.set(xlabel="Date",
       ylabel="SGD",
       title="Daily Exchange Rate for one SGD to Ringgit Malaysia, from 2000 to 2022")
 
plt.show()

# %%
# Challenge 1(b): Open and Plot a CSV File with Time Series Data

# Create figure and plot space
fig, ax = plt.subplots(figsize=(20, 15))
 
# Add x-axis and y-axis
ax.plot(xchange_rm_sgd_june_2000_june_2022.index.values,
        xchange_rm_sgd_june_2000_june_2022['SGD'],
        color='blue')
 
# Set title and labels for axes
ax.set(xlabel="Date",
       ylabel="SGD",
       title="Daily Exchange Rate for one SGD, from 2000 to 2022")
 
plt.show()

# %%
# Challenge 2(a): Open and Plot a CSV File with Time Series Data

# Create figure and plot space
fig, ax = plt.subplots(figsize=(20, 15))
 
# Add x-axis and y-axis
ax.scatter(xchange_rm_june_2000_june_2022.index.values,
        xchange_rm_june_2000_june_2022['USD'],
        color='blue')
 
# Set title and labels for axes
ax.set(xlabel="Date",
       ylabel="USD",
       title="Daily Exchange Rate for one USD to Ringgit Malaysia, from 2000 to 2022")
 
plt.show()

# %%
# Challenge 2(b): Open and Plot a CSV File with Time Series Data

# Create figure and plot space
fig, ax = plt.subplots(figsize=(20, 15))
 
# Add x-axis and y-axis
ax.plot(xchange_rm_june_2000_june_2022.index.values,
        xchange_rm_june_2000_june_2022['USD'],
        color='blue')
 
# Set title and labels for axes
ax.set(xlabel="Date",
       ylabel="USD",
       title="Daily Exchange Rate for one USD to Ringgit Malaysia, from 2000 to 2022")
 
plt.show()

# %%
# Challenge 3(a): Open and Plot a CSV File with Time Series Data

# Import necessary packages
from matplotlib.axes._axes import _log as matplotlib_axes_logger
import os
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import earthpy as et
import numpy as np

# Handle date time conversions between pandas and matplotlib
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# Dealing with error thrown by one of the plots
matplotlib_axes_logger.setLevel('ERROR')
import warnings
warnings.filterwarnings('ignore')

# Adjust font size and style of all plots in notebook with seaborn
sns.set(font_scale=1.5, style="whitegrid")

# Set working directory to earth-analytics
os.chdir(os.path.join(et.io.HOME, 
                      "earth-analytics", 
                      "data"))

# Import data from .csv file 
fname = os.path.join("forex",
                     "exchange-rates-rm-top10-june-2000-june-2022.csv")

# Import data using datetime and set index to datetime
xchange_rm_june_2000_june_2022 = pd.read_csv(fname,
                                parse_dates=['date'],
                                index_col=['date'])
xchange_rm_june_2000_june_2022

# Create figure and plot space
fig, ax = plt.subplots(figsize=(20, 15))
 
# Add x-axis and y-axis
ax.scatter(xchange_rm_june_2000_june_2022.index.values,
        xchange_rm_june_2000_june_2022['EUR'],
        color='blue')
 
# Set title and labels for axes
ax.set(xlabel="Date",
       ylabel="USD",
       title="Daily Exchange Rate for one EUR to Ringgit Malaysia, from 2000 to 2022")
 
plt.show()

# %%
# Challenge 3(b): Open and Plot a CSV File with Time Series Data

# Create figure and plot space
fig, ax = plt.subplots(figsize=(20, 15))
 
# Add x-axis and y-axis
ax.plot(xchange_rm_june_2000_june_2022.index.values,
        xchange_rm_june_2000_june_2022['EUR'],
        color='blue')
 
# Set title and labels for axes
ax.set(xlabel="Date",
       ylabel="USD",
       title="Daily Exchange Rate for one EUR to Ringgit Malaysia, from 2000 to 2022")
 
plt.show()

# %%
# Import necessary packages
from matplotlib.axes._axes import _log as matplotlib_axes_logger
import os
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import earthpy as et
import numpy as np

# Handle date time conversions between pandas and matplotlib
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# Dealing with error thrown by one of the plots
matplotlib_axes_logger.setLevel('ERROR')
import warnings
warnings.filterwarnings('ignore')

# Adjust font size and style of all plots in notebook with seaborn
sns.set(font_scale=1.5, style="whitegrid")

# Set working directory to earth-analytics
os.chdir(os.path.join(et.io.HOME, 
                      "earth-analytics", 
                      "data"))

# Import data from .csv file 
fname = os.path.join("forex",
                     "exchange-rates-rm-middle-10-june-2000-june-2022.csv")

# Import data using datetime and set index to datetime
xchange_rm_mid10_june_2000_june_2022 = pd.read_csv(fname,
                                parse_dates=['date'],
                                index_col=['date'])
xchange_rm_mid10_june_2000_june_2022
# Out:
#              THB100  PHP100   TWD100  KRW100  IDR100    SAR100     SDR  \
# date
# 2010-06-01  10.0861  7.0643  10.2072  0.2714  0.0356   87.4875  4.8372
# 2010-06-02  10.1581  7.0901  10.2502  0.2721  0.0358   88.2608  4.8422
# 2010-06-03  10.0399  7.0471  10.1850  0.2712  0.0356   87.1844  4.7924
# 2010-06-04  10.0368  7.0429  10.1690  0.2729  0.0356   87.1942  4.7912
# 2010-06-07  10.2112  7.1211  10.2822  0.2697  0.0359   88.9526  4.8758
# ...             ...     ...      ...     ...     ...       ...     ...
# 2022-06-07  12.7588  8.3080  14.8950  0.3499  0.0304  117.2252  5.9344
# 2022-06-08  12.7319  8.3034  14.8853  0.3496  0.0303  117.0959  5.9069
# 2022-06-09  12.7267  8.2966  14.8705  0.3498  0.0302  117.0794  5.9097
# 2022-06-10  12.6928  8.3082  14.8685  0.3474  0.0302  117.2910  5.9227
# 2022-06-13  12.6868  8.2907  14.8349  0.3428  0.0301  117.6894  5.9154
#
#                CNY     BND
# date
# 2010-06-01  0.4805  2.3454
# 2010-06-02  0.4845  2.3385
# ...

# %%
xchange_rm_mid10_june_2000_june_2022.describe()
# Out:
#             THB100       PHP100       TWD100       KRW100       IDR100  \
# count  2953.000000  2953.000000  2953.000000  2953.000000  2953.000000
# mean     11.627682     7.923212    12.462133     0.331163     0.030532
# std       1.357711     0.626694     1.711988     0.039208     0.002460
# min       9.701700     6.856000     9.742600     0.262600     0.026300
# 25%      10.129600     7.347500    10.595100     0.284900     0.028600
# 50%      11.877000     7.991100    13.041300     0.348200     0.029700
# 75%      12.770800     8.450500    13.997200     0.364500     0.032200
# max      13.858400     9.526600    15.249900     0.397800     0.036200
#
#             SAR100          SDR          CNY          BND
# count  2953.000000  2953.000000  2953.000000  2953.000000
# mean    100.112097     5.409494     0.574858     2.815707
# std      13.500311     0.509516     0.066002     0.280450
# min      78.355800     0.000000     0.455500     2.302500
# ...

# %%
# Challenge 4(a): Open and Plot a CSV File with Time Series Data

# Create figure and plot space
fig, ax = plt.subplots(figsize=(20, 15))
 
# Add x-axis and y-axis
ax.scatter(xchange_rm_mid10_june_2000_june_2022.index.values,
        xchange_rm_mid10_june_2000_june_2022['CNY'],
        color='blue')
 
# Set title and labels for axes
ax.set(xlabel="Date",
       ylabel="CNY",
       title="Daily Exchange Rate for one CNY to Ringgit Malaysia, from 2000 to 2022")
 
plt.show()

# %%
# Challenge 4(b): Open and Plot a CSV File with Time Series Data

# Create figure and plot space
fig, ax = plt.subplots(figsize=(20, 15))
 
# Add x-axis and y-axis
ax.plot(xchange_rm_mid10_june_2000_june_2022.index.values,
        xchange_rm_mid10_june_2000_june_2022['CNY'],
        color='blue')
 
# Set title and labels for axes
ax.set(xlabel="Date",
       ylabel="CNY",
       title="Daily Exchange Rate for one CNY to Ringgit Malaysia, from 2000 to 2022")
 
plt.show()

# %%
# Challenge 5: Open and Plot a CSV File with Time Series Data

# Create figure and plot space
fig, ax = plt.subplots(figsize=(20, 15))
 
# Add x-axis and y-axis
ax.scatter(xchange_rm_mid10_june_2000_june_2022.index.values,
        xchange_rm_mid10_june_2000_june_2022['THB100'],
        color='blue')
 
# Set title and labels for axes
ax.set(xlabel="Date",
       ylabel="THB100",
       title="Daily Exchange Rate for THB 100 to Ringgit Malaysia, from 2000 to 2022")
 
plt.show()

# %%
# Challenge 6: Open and Plot a CSV File with Time Series Data

# Create figure and plot space
fig, ax = plt.subplots(figsize=(20, 15))
 
# Add x-axis and y-axis
ax.scatter(xchange_rm_mid10_june_2000_june_2022.index.values,
        xchange_rm_mid10_june_2000_june_2022['PHP100'],
        color='blue')
 
# Set title and labels for axes
ax.set(xlabel="Date",
       ylabel="PHP100",
       title="Daily Exchange Rate for PHP 100 to Ringgit Malaysia, from 2000 to 2022")
 
plt.show()

# %%
# Challenge 6(b): Open and Plot a CSV File with Time Series Data

# Create figure and plot space
fig, ax = plt.subplots(figsize=(20, 15))
 
# Add x-axis and y-axis
ax.scatter(xchange_rm_mid10_june_2000_june_2022.index.values,
        xchange_rm_mid10_june_2000_june_2022['IDR100'],
        color='blue')
 
# Set title and labels for axes
ax.set(xlabel="Date",
       ylabel="IDR100",
       title="Daily Exchange Rate for IDR100 (Indonesia Rupiah) to Ringgit Malaysia, from 2000 to 2022")
 
plt.show()

# %%
# Import necessary packages
from matplotlib.axes._axes import _log as matplotlib_axes_logger
import os
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import earthpy as et
import numpy as np

# Handle date time conversions between pandas and matplotlib
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# Dealing with error thrown by one of the plots
matplotlib_axes_logger.setLevel('ERROR')
import warnings
warnings.filterwarnings('ignore')

# Adjust font size and style of all plots in notebook with seaborn
sns.set(font_scale=1.5, style="whitegrid")

# Set working directory to earth-analytics
os.chdir(os.path.join(et.io.HOME, 
                      "earth-analytics", 
                      "data"))

# Import data from .csv file 
fname = os.path.join("forex",
                     "exchange-rates-rm-bottom-10-june-2000-june-2022.csv")

# Import data using datetime and set index to datetime
xchange_rm_bottom10_june_2000_june_2022 = pd.read_csv(fname,
                                parse_dates=['DATE'],
                                index_col=['DATE'])
xchange_rm_bottom10_june_2000_june_2022
# Out:
#             VND100  KHR100     NZD  MMK100  INR100    AED100  PKR100  NPR100  \
# DATE
# 2010-06-01  0.0173  0.0779  2.2183  0.0000  0.0000    0.0000  0.0000  0.0000
# 2010-06-02  0.0174  0.0786  2.2339  0.0000  0.0000    0.0000  0.0000  0.0000
# 2010-06-03  0.0172  0.0774  2.2375  0.0000  0.0000    0.0000  0.0000  0.0000
# 2010-06-04  0.0172  0.0776  2.2347  0.0000  0.0000    0.0000  0.0000  0.0000
# 2010-06-07  0.0176  0.0790  2.2091  0.0000  0.0000    0.0000  0.0000  0.0000
# ...            ...     ...     ...     ...     ...       ...     ...     ...
# 2022-06-07  0.0190  0.1079  2.8451  0.2377  5.6584  119.7098  2.1953  3.5364
# 2022-06-08  0.0189  0.1079  2.8380  0.2374  5.6540  119.5873  2.1670  3.5335
# 2022-06-09  0.0189  0.1078  2.8335  0.2374  5.6489  119.5737  2.1933  3.5305
# 2022-06-10  0.0190  0.1080  2.8154  0.2378  5.6535  119.7642  2.1782  3.5329
# 2022-06-13  0.0190  0.1084  2.7991  0.2386  5.6460  120.1998  2.1851  3.5278
#
#                EGP
# DATE
# ...

# %%
# Challenge 6: Open and Plot a CSV File with Time Series Data

# Create figure and plot space
fig, ax = plt.subplots(figsize=(20, 15))
 
# Add x-axis and y-axis
ax.scatter(xchange_rm_bottom10_june_2000_june_2022.index.values,
        xchange_rm_bottom10_june_2000_june_2022['NZD'],
        color='blue')
 
# Set title and labels for axes
ax.set(xlabel="Date",
       ylabel="NZD",
       title="Daily Exchange Rate for one NZD to Ringgit Malaysia, from 2000 to 2022")
 
plt.show()

# %%
# Challenge 6: Open and Plot a CSV File with Time Series Data

# Create figure and plot space
fig, ax = plt.subplots(figsize=(20, 15))
 
# Add x-axis and y-axis
ax.scatter(xchange_rm_bottom10_june_2000_june_2022.index.values,
        xchange_rm_bottom10_june_2000_june_2022['VND100'],
        color='blue')
 
# Set title and labels for axes
ax.set(xlabel="Date",
       ylabel="VND100",
       title="Daily Exchange Rate for VND100 to Ringgit Malaysia, from 2000 to 2022")
 
plt.show()

# %%
# Challenge 6: Open and Plot a CSV File with Time Series Data

# Create figure and plot space
fig, ax = plt.subplots(figsize=(20, 15))
 
# Add x-axis and y-axis
ax.scatter(xchange_rm_bottom10_june_2000_june_2022.index.values,
        xchange_rm_bottom10_june_2000_june_2022['INR100'],
        color='blue')
 
# Set title and labels for axes
ax.set(xlabel="Date",
       ylabel="INR100",
       title="Daily Exchange Rate for INR100 (India Rupee) to Ringgit Malaysia, from 2000 to 2022")
 
plt.show()
